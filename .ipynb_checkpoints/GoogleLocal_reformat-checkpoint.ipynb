# %%
import csv
import numpy as np
import random
import matplotlib.pyplot as plt
import math
import time

import pandas as pd

# %% [markdown]
# # Build Review dataset using user and place indices

# %%
reviews = pd.read_csv("../datasets/google_local/reviews.csv")
display(reviews.info())
display(reviews.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11453845 entries, 0 to 11453844
# Data columns (total 4 columns):
# gPlusPlaceId      object
# gPlusUserId       object
# rating            float64
# unixReviewTime    object
# dtypes: float64(1), object(3)
# memory usage: 349.5+ MB
# None
#             gPlusPlaceId            gPlusUserId  rating unixReviewTime
# 0  108103314380004200232  100000010817154263736     3.0     1372686659
# 1  102194128241608748649  100000013500285534661     5.0     1342870724
# 2  101409858828175402384  100000021336848867366     5.0     1390653513
# 3  101477177500158511502  100000021336848867366     5.0     1389187706
# 4  106994170641063333085  100000021336848867366     4.0     1390486279

# %%
place_ids = list(reviews['gPlusPlaceId'].unique())
user_ids = list(reviews['gPlusUserId'].unique())

place_ids.sort()
user_ids.sort()

print(len(place_ids), place_ids[:3])
print(len(user_ids), user_ids[:3])
# Out:
# 3116785 ['100000007848517518160', '100000027961183785551', '100000028989488322699']
# 5054567 ['100000010817154263736', '100000013500285534661', '100000021336848867366']

# %% [markdown]
# ### Replace IDs with Indices

# %%
start = time.time()

from bisect import bisect_left 
  
def BinarySearch(a, x): 
    i = bisect_left(a, x) 
    if i != len(a) and a[i] == x: 
        return i 
    else: 
        return -1

for i in reviews.index:
    if i%100000==0:
        print(time.time()-start)
        start = time.time()
        print(i)
    pid = reviews.at[i,'gPlusPlaceId']
    uid = reviews.at[i,'gPlusUserId']

    reviews.at[i,'gPlusPlaceId'] = BinarySearch(place_ids,pid)
    reviews.at[i,'gPlusUserId'] = BinarySearch(user_ids,uid)
# Out:
# 0.2108461856842041
# 0
# 5.007460594177246
# 100000
# 4.743478059768677
# 200000
# 4.939120531082153
# 300000
# 4.669917583465576
# 400000
# 5.119900226593018
# 500000
# 4.73084020614624
# 600000
# 4.80470085144043
# 700000
# 4.740260362625122
# 800000
# 4.993489503860474
# 900000
# 4.868492603302002
# 1000000
# 4.786747217178345
# 1100000
# 4.9740073680877686
# 1200000
# 4.781872272491455
# 1300000
# 5.226130247116089
# 1400000
# 4.79388427734375
# 1500000
# 4.857175827026367
# 1600000
# 4.732042551040649
# 1700000
# 4.788888931274414
# 1800000
# 4.728853464126587
# 1900000
# 4.73508620262146
# 2000000
# 4.781548023223877
# 2100000
# 4.7074689865112305
# 2200000
# 5.060934782028198
# 2300000
# 4.9958274364471436
# 2400000
# 5.124858140945435
# 2500000
# 4.90395712852478
# 2600000
# 5.271379709243774
# 2700000
# 5.298417568206787
# 2800000
# 5.109431505203247
# 2900000
# 4.716844081878662
# 3000000
# 4.904526472091675
# 3100000
# 4.850224494934082
# 3200000
# 5.091361045837402
# 3300000
# 4.997869491577148
# 3400000
# 4.9076759815216064
# 3500000
# 4.718376636505127
# 3600000
# 4.892521858215332
# 3700000
# 5.285653591156006
# 3800000
# 5.029468059539795
print(reviews[:10])

reviews.to_csv(fname, encoding='utf-8', index=False)
# Out:
#   gPlusPlaceId gPlusUserId  rating unixReviewTime
# 0      1368311           0     3.0     1372686659
# 1       370282           1     5.0     1342870724
# 2       237940           2     5.0     1390653513
# 3       249417           2     5.0     1389187706
# 4      1181533           2     4.0     1390486279
# 5      1257074           2     5.0     1390192729
# 6      1350634           2     5.0     1390825528
# 7      1919338           2     4.0     1390445561
# 8      2018069           2     4.0     1390387529
# 9      2348090           2     5.0     1392295463

# %%
fname = "../datasets/google_local/user_reformatted.csv"

users = pd.Series(user_ids)

print(users[:10])

users.to_csv(fname, encoding='utf-8', index=True)
# Out:
# 0    100000010817154263736
# 1    100000013500285534661
# 2    100000021336848867366
# 3    100000030557048145331
# 4    100000032416892623125
# 5    100000035085750632094
# 6    100000036174088924566
# 7    100000037905537879319
# 8    100000039815955317902
# 9    100000042779388982190
# dtype: object

# %%
fname = "../datasets/google_local/place_reformatted.csv"

places = pd.Series(place_ids)

print(places[:10])

places.to_csv(fname, encoding='utf-8', index=True)
# Out:
# 0    100000007848517518160
# 1    100000027961183785551
# 2    100000028989488322699
# 3    100000030371226927960
# 4    100000031133105350522
# 5    100000038035038453021
# 6    100000061163388376076
# 7    100000061963763467148
# 8    100000075541128264108
# 9    100000077955167136431
# dtype: object

# %%
reviews = pd.read_csv("../datasets/google_local/reviews_reformatted.csv")
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11453845 entries, 0 to 11453844
# Data columns (total 4 columns):
# gPlusPlaceId      int64
# gPlusUserId       int64
# rating            float64
# unixReviewTime    object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 349.5+ MB

# %%
freq = reviews['gPlusPlaceId'].value_counts()
sorted_freq = freq.sort_index()

sorted_freq[-15:]
# Out:
# 3116770     1
# 3116771    36
# 3116772     8
# 3116773     1
# 3116774     2
# 3116775     3
# 3116776     1
# 3116777     1
# 3116778     2
# 3116779     5
# 3116780     1
# 3116781     1
# 3116782     4
# 3116783     4
# 3116784     8
# Name: gPlusPlaceId, dtype: int64

# %%
reviews[reviews['gPlusPlaceId']==3116771]
# Out:
#           gPlusPlaceId  gPlusUserId  rating unixReviewTime  num_reviews
# 695185         3116771       301121     4.0     1367080096            0
# 1211764        3116771       527596     5.0           None            0
# 1436329        3116771       625738     5.0     1367856841            0
# 1575882        3116771       686192     5.0     1365600379            0
# 1772394        3116771       773476     4.0     1362242565            0
# 2300117        3116771      1002057     4.0     1364826387            0
# 2680484        3116771      1170158     5.0     1373298541            0
# 2972092        3116771      1297721     5.0     1361140881            0
# 3176259        3116771      1386118     4.0     1364071866            0
# 4081150        3116771      1786010     5.0     1373487756            0
# 4110522        3116771      1799259     4.0     1368301562            0
# 4652591        3116771      2037539     4.0     1362919544            0
# 4762780        3116771      2086969     4.0     1361749301            0
# 4984787        3116771      2184698     4.0     1360440117            0
# 5341945        3116771      2341241     5.0     1360690719            0
# 5811358        3116771      2546814     4.0     1368205047            0
# 6205494        3116771      2722923     4.0     1362334331            0
# 6327531        3116771      2776466     5.0     1363043279            0
# 7144557        3116771      3134820     5.0     1370908216            0
# 7379952        3116771      3239268     5.0     1367498192            0
# 7739059        3116771      3397621     4.0     1383613298            0
# 8000126        3116771      3513310     4.0     1363466527            0
# 8384495        3116771      3682604     3.0     1395779192            0
# 8592255        3116771      3774400     5.0     1375541783            0
# 9091695        3116771      3993602     5.0     1328069521            0
# 9120044        3116771      4006297     5.0     1365189279            0
# 9414501        3116771      4136437     4.0     1387638769            0
# 9561942        3116771      4200896     5.0     1388704842            0
# 10023561       3116771      4406716     4.0     1393876680            0
# 10203538       3116771      4489318     5.0     1387367577            0
# 10455882       3116771      4603875     5.0     1362595182            0
# 10513924       3116771      4630150     5.0     1363473505            0
# 10712361       3116771      4717561     5.0           None            0
# 10934310       3116771      4819380     5.0           None            0
# 11134207       3116771      4909210     5.0     1340809629            0
# 11327115       3116771      4997675     5.0     1360878589            0

# %%
reviews['num_reviews'] = 0

reviews.head()
# Out:
#    gPlusPlaceId  gPlusUserId  rating unixReviewTime  num_reviews
# 0       1368311            0     3.0     1372686659            0
# 1        370282            1     5.0     1342870724            0
# 2        237940            2     5.0     1390653513            0
# 3        249417            2     5.0     1389187706            0
# 4       1181533            2     4.0     1390486279            0

# %%
from bisect import bisect_left 
  
def BinarySearch(a, x): 
    i = bisect_left(a, x) 
    if i != len(a) and a[i] == x: 
        return i 
    else: 
        return -1

freqs = list(sorted_freq)
    
start = time.time()

for i in reviews.index:
    if i%100000==0:
        print(time.time()-start)
        start = time.time()
        print(i)
    pid = reviews.at[i,'gPlusPlaceId']
    reviews.at[i,'num_reviews'] = freqs[pid]
# Out:
# 0.0003368854522705078
# 0
# 42.292922258377075
# 100000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-be4e43e5d234> in <module>()
#      16         print(i)
#      17     pid = reviews.at[i,'gPlusPlaceId']
# ---> 18     reviews.at[i,'num_reviews'] = BinarySearch(sorted_freq,pid)
#
# <ipython-input-14-be4e43e5d234> in BinarySearch(a, x)
#       2
#       3 def BinarySearch(a, x):
# ----> 4     i = bisect_left(a, x)
#       5     if i != len(a) and a[i] == x:
#       6         return i
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# KeyboardInterrupt:

# %%
reviews.head()
# Out:
#    gPlusPlaceId  gPlusUserId  rating unixReviewTime  num_reviews
# 0       1368311            0     3.0     1372686659           -1
# 1        370282            1     5.0     1342870724           -1
# 2        237940            2     5.0     1390653513           -1
# 3        249417            2     5.0     1389187706           -1
# 4       1181533            2     4.0     1390486279           -1

# %%
pid = reviews.at[0,'gPlusPlaceId']

print(pid)

freq = BinarySearch(sorted_freq,pid)
# Out:
# 1368311

# %%
sorted_freq[pid]
# Out:
# 3
